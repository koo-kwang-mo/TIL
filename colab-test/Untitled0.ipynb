# %%
print('hello_git')

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
cd /content/drive/MyDrive/Gitcommit/TIL

# %%
# !git config --global user.email 'dpqpfptmxm3@naver.com'
# !git config --global user.name 'koo-kwang-mo'

# %%
# !git add Untitle.ipynb

# %%
# !git commit -m 'git-test'
# !git push
